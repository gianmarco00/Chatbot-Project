# %%
from rdflib.term import URIRef, Literal
import rdflib

# %%
import re
import editdistance

# %% [markdown]
# ### Import the knowledge graph

# %%
graph = rdflib.Graph()
graph.parse('/Users/gianmarcoalbano/Desktop/Advanced topics in AI/Speakeasy Project/Datasets/14_graph.nt', format='turtle')
# Out:
# <Graph identifier=N647463251d334519b4912ed2bf80bf01 (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# ### Some info on the knowledge graph
#
# The entities are stored with different URIs. The most common namespaces are the following:

# %%
# define some prefixes
WD = rdflib.Namespace('http://www.wikidata.org/entity/')
WDT = rdflib.Namespace('http://www.wikidata.org/prop/direct/')
DDIS = rdflib.Namespace('http://ddis.ch/atai/')
RDFS = rdflib.namespace.RDFS
SCHEMA = rdflib.Namespace('http://schema.org/')

# %%
print('Some subjects from the knowledge graph')
for objs in list(set(graph.subjects()))[:10]:
    print(objs)
    
print('\n Some objects from the knowledge graph')
for objs in list(set(graph.objects()))[10:20]:
    print(objs)
# Out:
# Some subjects from the knowledge graph
# http://www.wikidata.org/entity/Q3701012
# http://www.wikidata.org/entity/Q3547244
# http://www.wikidata.org/entity/Q2159242
# http://www.wikidata.org/entity/Q1273264
# http://www.wikidata.org/entity/Q7612508
# http://www.wikidata.org/entity/Q392915
# http://www.wikidata.org/entity/Q1374891
# http://www.wikidata.org/entity/Q4455695
# http://www.wikidata.org/entity/Q14954903
# http://www.wikidata.org/entity/Q635352
#
#  Some objects from the knowledge graph
# 1995 film by Paolo Virzì
# nm0221657
# http://www.wikidata.org/entity/Q1273264
# http://www.wikidata.org/entity/Q7612508
# http://www.wikidata.org/entity/Q1374891
# http://www.wikidata.org/entity/Q4455695
# tt1336988
# http://www.wikidata.org/entity/Q14954903
# American actor (1891-1938)
# 2019 film by Ladj Ly

# %% [markdown]
# Some ways to access the label of an entity in the graph subjects given it's URI:

# %%
for node in graph.subjects():
    if graph.value(subject=node, predicate=RDFS.label): # Check if the triple exists
        print(f"node {node} has label {graph.value(subject=node, predicate=RDFS.label)}")
    break
# Out:
# node http://www.wikidata.org/entity/Q320417 has label A Map of the World

# %% [markdown]
# We want to check if every subject in the graph has a label

# %%
i = 0
j = 0
for node in graph.subjects():
    j += 1
    if graph.value(subject=node, predicate=RDFS.label): # Check if the triple exists
        i += 1

print(f"Number of subjects with a label: {i}\n")
print(f"Number of subjects in the graph: {j}\n")
if i != j:
    print(f"There are {j-i} subject entities without a label")
# Out:
# Number of subjects with a label: 2051387
#
# Number of subjects in the graph: 2056777
#
# There are 5390 subject entities without a label

# %%
for node in graph.subjects():
    if graph.value(subject=node, predicate=RDFS.label) == None:
        print(f"entity {node} has no label")
# Out:
# entity http://www.wikidata.org/entity/Q94685087 has no label
# entity http://www.wikidata.org/entity/Q23827934 has no label
# entity http://www.wikidata.org/entity/Q101245050 has no label
# entity http://www.wikidata.org/entity/Q65092062 has no label
# entity http://www.wikidata.org/entity/Q104631284 has no label
# entity http://www.wikidata.org/entity/Q2688886 has no label
# entity http://www.wikidata.org/entity/Q15849464 has no label
# entity http://www.wikidata.org/entity/Q55598789 has no label
# entity http://www.wikidata.org/entity/Q4197865 has no label
# entity http://www.wikidata.org/entity/Q5980862 has no label
# entity http://www.wikidata.org/entity/Q2937568 has no label
# entity http://www.wikidata.org/entity/Q86725850 has no label
# entity http://www.wikidata.org/entity/Q106464367 has no label
# entity http://www.wikidata.org/entity/Q102315151 has no label
# entity http://www.wikidata.org/entity/Q20636406 has no label
# entity http://www.wikidata.org/entity/Q106473918 has no label
# entity http://www.wikidata.org/entity/Q11573283 has no label
# entity http://www.wikidata.org/entity/Q10822396 has no label
# entity http://www.wikidata.org/entity/Q101049393 has no label
# entity http://www.wikidata.org/entity/Q30740620 has no label
# entity http://www.wikidata.org/entity/Q101210278 has no label
# entity http://www.wikidata.org/entity/Q5837386 has no label
# entity http://www.wikidata.org/entity/Q64976137 has no label
# entity http://www.wikidata.org/entity/Q4688605 has no label
# entity http://www.wikidata.org/entity/Q3070481 has no label
# entity http://www.wikidata.org/entity/Q102361537 has no label
# entity http://www.wikidata.org/entity/Q69032012 has no label
# entity http://www.wikidata.org/entity/Q30942216 has no label
# entity http://www.wikidata.org/entity/Q106211456 has no label
# entity http://www.wikidata.org/entity/Q3233349 has no label
# entity http://www.wikidata.org/entity/Q3234830 has no label
# entity http://www.wikidata.org/entity/Q41695165 has no label
# entity http://www.wikidata.org/entity/Q100972640 has no label
# entity http://www.wikidata.org/entity/Q6343185 has no label
# entity http://www.wikidata.org/entity/Q102336419 has no label
# entity http://www.wikidata.org/entity/Q106464367 has no label
# entity http://www.wikidata.org/entity/Q106473747 has no label
# entity http://www.wikidata.org/entity/Q1192986 has no label
# entity http://www.wikidata.org/entity/Q72544914 has no label
# entity http://www.wikidata.org/entity/Q3226052 has no label
# entity http://www.wikidata.org/entity/Q12624111 has no label
# entity http://www.wikidata.org/entity/Q20580507 has no label
# entity http://www.wikidata.org/entity/Q99641832 has no label
# entity http://www.wikidata.org/entity/Q106159919 has no label
# entity http://www.wikidata.org/entity/Q27942467 has no label
# entity http://www.wikidata.org/entity/Q15221756 has no label
# entity http://www.wikidata.org/entity/Q20059156 has no label
# entity http://www.wikidata.org/entity/Q105581951 has no label
# entity http://www.wikidata.org/entity/Q24014292 has no label
# entity http://www.wikidata.org/entity/Q4029764 has no label
# entity http://www.wikidata.org/entity/Q64976119 has no label
# entity http://www.wikidata.org/entity/Q4197865 has no label
# entity http://www.wikidata.org/entity/Q30119440 has no label
# entity http://www.wikidata.org/entity/Q22683724 has no label
# entity http://www.wikidata.org/entity/Q3220531 has no label
# entity http://www.wikidata.org/entity/Q12100227 has no label
# entity http://www.wikidata.org/entity/Q27819785 has no label
# entity http://www.wikidata.org/entity/Q3953393 has no label
# entity http://www.wikidata.org/entity/Q59367368 has no label
# entity http://www.wikidata.org/entity/Q102350582 has no label
# entity http://www.wikidata.org/entity/Q1212172 has no label
# entity http://www.wikidata.org/entity/Q106127885 has no label
# entity http://www.wikidata.org/entity/Q66809944 has no label
# entity http://www.wikidata.org/entity/Q41695165 has no label
# entity http://www.wikidata.org/entity/Q18412226 has no label
# entity http://www.wikidata.org/entity/Q16262597 has no label
# entity http://www.wikidata.org/entity/Q30740620 has no label
# entity http://www.wikidata.org/entity/Q50848743 has no label
# entity http://www.wikidata.org/entity/Q20001157 has no label
# entity http://www.wikidata.org/entity/Q104641594 has no label
# entity http://www.wikidata.org/entity/Q12747927 has no label
# entity http://www.wikidata.org/entity/Q74252500 has no label
# entity http://www.wikidata.org/entity/Q11573283 has no label
# entity http://www.wikidata.org/entity/Q3070842 has no label
# entity http://www.wikidata.org/entity/Q106473747 has no label
# entity http://www.wikidata.org/entity/Q91336640 has no label
# entity http://www.wikidata.org/entity/Q16141765 has no label
# entity http://www.wikidata.org/entity/Q2500338 has no label
# entity http://www.wikidata.org/entity/Q5780686 has no label
# entity http://www.wikidata.org/entity/Q104129265 has no label
# entity http://www.wikidata.org/entity/Q28563829 has no label
# entity http://www.wikidata.org/entity/Q5856317 has no label
# entity http://www.wikidata.org/entity/Q21334186 has no label
# entity http://www.wikidata.org/entity/Q2113260 has no label
# entity http://www.wikidata.org/entity/Q104640512 has no label
# entity http://www.wikidata.org/entity/Q1742568 has no label
# entity http://www.wikidata.org/entity/Q3624680 has no label
# entity http://www.wikidata.org/entity/Q30119440 has no label
# entity http://www.wikidata.org/entity/Q16434093 has no label
# entity http://www.wikidata.org/entity/Q3441291 has no label
# entity http://www.wikidata.org/entity/Q12445349 has no label
# entity http://www.wikidata.org/entity/Q3069871 has no label
# entity http://www.wikidata.org/entity/Q11784265 has no label
# entity http://www.wikidata.org/entity/Q30119440 has no label
# entity http://www.wikidata.org/entity/Q28017210 has no label
# entity http://www.wikidata.org/entity/Q55597835 has no label
# entity http://www.wikidata.org/entity/Q100972640 has no label
# entity http://www.wikidata.org/entity/Q101082381 has no label
# entity http://www.wikidata.org/entity/Q12308800 has no label
# entity http://www.wikidata.org/entity/Q79017770 has no label
# entity http://www.wikidata.org/entity/Q64692313 has no label
# entity http://www.wikidata.org/entity/Q103824897 has no label
# entity http://www.wikidata.org/entity/Q5645791 has no label
# entity http://www.wikidata.org/entity/Q16635235 has no label
# entity http://www.wikidata.org/entity/Q5869412 has no label
# entity http://www.wikidata.org/entity/Q3624680 has no label
# entity http://www.wikidata.org/entity/Q101048596 has no label
# entity http://www.wikidata.org/entity/Q2096409 has no label
# entity http://www.wikidata.org/entity/Q21655332 has no label
# entity http://www.wikidata.org/entity/Q56641079 has no label
# entity http://www.wikidata.org/entity/Q103830488 has no label
# entity http://www.wikidata.org/entity/Q15875834 has no label
# entity http://www.wikidata.org/entity/Q84770361 has no label
# entity http://www.wikidata.org/entity/Q4029764 has no label
# entity http://www.wikidata.org/entity/Q6048077 has no label
# entity http://www.wikidata.org/entity/Q30119440 has no label
# entity http://www.wikidata.org/entity/Q4099138 has no label
# entity http://www.wikidata.org/entity/Q24051689 has no label
# entity http://www.wikidata.org/entity/Q5690317 has no label
# entity http://www.wikidata.org/entity/Q74252500 has no label
# entity http://www.wikidata.org/entity/Q56479557 has no label
# entity http://www.wikidata.org/entity/Q102337783 has no label
# entity http://www.wikidata.org/entity/Q16332388 has no label
# entity http://www.wikidata.org/entity/Q8247157 has no label
# entity http://www.wikidata.org/entity/Q10822396 has no label
# entity http://www.wikidata.org/entity/Q104626136 has no label
# entity http://www.wikidata.org/entity/Q25439924 has no label
# entity http://www.wikidata.org/entity/Q104590818 has no label
# entity http://www.wikidata.org/entity/Q12100227 has no label
# entity http://www.wikidata.org/entity/Q8247157 has no label
# entity http://www.wikidata.org/entity/Q4060426 has no label
# entity http://www.wikidata.org/entity/Q12034863 has no label
# entity http://www.wikidata.org/entity/Q16675753 has no label
# entity http://www.wikidata.org/entity/Q18697224 has no label
# entity http://www.wikidata.org/entity/Q33103003 has no label
# entity http://www.wikidata.org/entity/Q6343182 has no label
# entity http://www.wikidata.org/entity/Q20493926 has no label
# entity http://www.wikidata.org/entity/Q11328842 has no label
# entity http://www.wikidata.org/entity/Q23498085 has no label
# entity http://www.wikidata.org/entity/Q86504398 has no label
# entity http://www.wikidata.org/entity/Q105724040 has no label
# entity http://www.wikidata.org/entity/Q786133 has no label
# entity http://www.wikidata.org/entity/Q104836893 has no label
# entity http://www.wikidata.org/entity/Q61747706 has no label
# entity http://www.wikidata.org/entity/Q873894 has no label
# entity http://www.wikidata.org/entity/Q22001258 has no label
# entity http://www.wikidata.org/entity/Q104641594 has no label
# entity http://www.wikidata.org/entity/Q102361446 has no label
# entity http://www.wikidata.org/entity/Q106158648 has no label
# entity http://www.wikidata.org/entity/Q6048077 has no label
# entity http://www.wikidata.org/entity/Q10260523 has no label
# entity http://www.wikidata.org/entity/Q106214020 has no label
# entity http://www.wikidata.org/entity/Q4526480 has no label
# entity http://www.wikidata.org/entity/Q31733987 has no label
# entity http://www.wikidata.org/entity/Q21858493 has no label
# entity http://www.wikidata.org/entity/Q2113260 has no label
# entity http://www.wikidata.org/entity/Q104626209 has no label
# entity http://www.wikidata.org/entity/Q4197865 has no label
# entity http://www.wikidata.org/entity/Q106634975 has no label
# entity http://www.wikidata.org/entity/Q4177256 has no label
# entity http://www.wikidata.org/entity/Q3639426 has no label
# entity http://www.wikidata.org/entity/Q100977204 has no label
# entity http://www.wikidata.org/entity/Q16482238 has no label
# entity http://www.wikidata.org/entity/Q104640564 has no label
# entity http://www.wikidata.org/entity/Q8774107 has no label
# entity http://www.wikidata.org/entity/Q22968325 has no label
# entity http://www.wikidata.org/entity/Q16745128 has no label
# entity http://www.wikidata.org/entity/Q12321398 has no label
# entity http://www.wikidata.org/entity/Q3224036 has no label
# entity http://www.wikidata.org/entity/Q17263964 has no label
# entity http://www.wikidata.org/entity/Q102361537 has no label
# entity http://www.wikidata.org/entity/Q9315645 has no label
# entity http://www.wikidata.org/entity/Q104599100 has no label
# entity http://www.wikidata.org/entity/Q20817092 has no label
# entity http://www.wikidata.org/entity/Q8774107 has no label
# entity http://www.wikidata.org/entity/Q3821416 has no label
# entity http://www.wikidata.org/entity/Q47155153 has no label
# entity http://www.wikidata.org/entity/Q51879417 has no label
# entity http://www.wikidata.org/entity/Q20493926 has no label
# entity http://www.wikidata.org/entity/Q16938162 has no label
# entity http://www.wikidata.org/entity/Q13014724 has no label
# entity http://www.wikidata.org/entity/Q106464367 has no label
# entity http://www.wikidata.org/entity/Q1533391 has no label
# entity http://www.wikidata.org/entity/Q21040543 has no label
# entity http://www.wikidata.org/entity/Q96755095 has no label
# entity http://www.wikidata.org/entity/Q6053638 has no label
# entity http://www.wikidata.org/entity/Q551580 has no label
# entity http://www.wikidata.org/entity/Q4123503 has no label
# entity http://www.wikidata.org/entity/Q15221756 has no label
# entity http://www.wikidata.org/entity/Q2096409 has no label
# entity http://www.wikidata.org/entity/Q2108414 has no label
# entity http://www.wikidata.org/entity/Q104853864 has no label
# entity http://www.wikidata.org/entity/Q103703607 has no label
# entity http://www.wikidata.org/entity/Q55597835 has no label
# entity http://www.wikidata.org/entity/Q5770883 has no label
# entity http://www.wikidata.org/entity/Q101112643 has no label
# entity http://www.wikidata.org/entity/Q102334558 has no label
# entity http://www.wikidata.org/entity/Q3234830 has no label
# entity http://www.wikidata.org/entity/Q27517873 has no label
# entity http://www.wikidata.org/entity/Q28974159 has no label
# entity http://www.wikidata.org/entity/Q3624680 has no label
# entity http://www.wikidata.org/entity/Q24862746 has no label
# entity http://www.wikidata.org/entity/Q12781509 has no label
# entity http://www.wikidata.org/entity/Q18003149 has no label
# entity http://www.wikidata.org/entity/Q5391592 has no label
# entity http://www.wikidata.org/entity/Q104591082 has no label
# entity http://www.wikidata.org/entity/Q13014724 has no label
# entity http://www.wikidata.org/entity/Q86725944 has no label
# entity http://www.wikidata.org/entity/Q15154773 has no label
# entity http://www.wikidata.org/entity/Q86724612 has no label
# entity http://www.wikidata.org/entity/Q47155153 has no label
# entity http://www.wikidata.org/entity/Q2688886 has no label
# entity http://www.wikidata.org/entity/Q3703467 has no label
# entity http://www.wikidata.org/entity/Q105724040 has no label
# entity http://www.wikidata.org/entity/Q101244878 has no label
# entity http://www.wikidata.org/entity/Q18697224 has no label
# entity http://www.wikidata.org/entity/Q4526480 has no label
# entity http://www.wikidata.org/entity/Q30119440 has no label
# entity http://www.wikidata.org/entity/Q86427065 has no label
# entity http://www.wikidata.org/entity/Q7218083 has no label
# entity http://www.wikidata.org/entity/Q16128799 has no label
# entity http://www.wikidata.org/entity/Q1533391 has no label
# entity http://www.wikidata.org/entity/Q5770883 has no label
# entity http://www.wikidata.org/entity/Q106158648 has no label
# entity http://www.wikidata.org/entity/Q2096409 has no label
# entity http://www.wikidata.org/entity/Q11478170 has no label
# entity http://www.wikidata.org/entity/Q3233349 has no label
# entity http://www.wikidata.org/entity/Q104129120 has no label
# entity http://www.wikidata.org/entity/Q2454505 has no label
# entity http://www.wikidata.org/entity/Q27962009 has no label
# entity http://www.wikidata.org/entity/Q102346114 has no label
# entity http://www.wikidata.org/entity/Q101210278 has no label
# entity http://www.wikidata.org/entity/Q19530268 has no label
# entity http://www.wikidata.org/entity/Q3576574 has no label
# entity http://www.wikidata.org/entity/Q96755095 has no label
# entity http://www.wikidata.org/entity/Q87725751 has no label
# entity http://www.wikidata.org/entity/Q2096409 has no label
# entity http://www.wikidata.org/entity/Q20495360 has no label
# entity http://www.wikidata.org/entity/Q106128636 has no label
# entity http://www.wikidata.org/entity/Q11789223 has no label
# entity http://www.wikidata.org/entity/Q3729239 has no label
# entity http://www.wikidata.org/entity/Q11781176 has no label
# entity http://www.wikidata.org/entity/Q102428100 has no label
# entity http://www.wikidata.org/entity/Q65092119 has no label
# entity http://www.wikidata.org/entity/Q26186248 has no label
# entity http://www.wikidata.org/entity/Q106215116 has no label
# entity http://www.wikidata.org/entity/Q20729380 has no label
# entity http://www.wikidata.org/entity/Q1533391 has no label
# entity http://www.wikidata.org/entity/Q47500835 has no label
# entity http://www.wikidata.org/entity/Q106180515 has no label
# entity http://www.wikidata.org/entity/Q3212518 has no label
# entity http://www.wikidata.org/entity/Q28974159 has no label
# entity http://www.wikidata.org/entity/Q106269043 has no label
# entity http://www.wikidata.org/entity/Q1204806 has no label
# entity http://www.wikidata.org/entity/Q99328660 has no label
# entity http://www.wikidata.org/entity/Q19516219 has no label
# entity http://www.wikidata.org/entity/Q16938162 has no label
# entity http://www.wikidata.org/entity/Q3548664 has no label
# entity http://www.wikidata.org/entity/Q23784054 has no label
# entity http://www.wikidata.org/entity/Q1969749 has no label
# entity http://www.wikidata.org/entity/Q3575712 has no label
# entity http://www.wikidata.org/entity/Q101050864 has no label
# entity http://www.wikidata.org/entity/Q18291034 has no label
# entity http://www.wikidata.org/entity/Q30879053 has no label
# entity http://www.wikidata.org/entity/Q3208072 has no label
# entity http://www.wikidata.org/entity/Q33103003 has no label
# entity http://www.wikidata.org/entity/Q5837386 has no label
# entity http://www.wikidata.org/entity/Q12321770 has no label
# entity http://www.wikidata.org/entity/Q3226052 has no label
# entity http://www.wikidata.org/entity/Q10884462 has no label
# entity http://www.wikidata.org/entity/Q101588992 has no label
# entity http://www.wikidata.org/entity/Q3322711 has no label
# entity http://www.wikidata.org/entity/Q103825861 has no label
# entity http://www.wikidata.org/entity/Q104640512 has no label
# entity http://www.wikidata.org/entity/Q5391592 has no label
# entity http://www.wikidata.org/entity/Q103845096 has no label
# entity http://www.wikidata.org/entity/Q8247157 has no label
# entity http://www.wikidata.org/entity/Q102802045 has no label
# entity http://www.wikidata.org/entity/Q22968325 has no label
# entity http://www.wikidata.org/entity/Q3227598 has no label
# entity http://www.wikidata.org/entity/Q4003531 has no label
# entity http://www.wikidata.org/entity/Q4375133 has no label
# entity http://www.wikidata.org/entity/Q11318535 has no label
# entity http://www.wikidata.org/entity/Q20181396 has no label
# entity http://www.wikidata.org/entity/Q65092084 has no label
# entity http://www.wikidata.org/entity/Q105452943 has no label
# entity http://www.wikidata.org/entity/Q30119440 has no label
# entity http://www.wikidata.org/entity/Q102422895 has no label
# entity http://www.wikidata.org/entity/Q106128835 has no label
# entity http://www.wikidata.org/entity/Q3224036 has no label
# entity http://www.wikidata.org/entity/Q3224036 has no label
# entity http://www.wikidata.org/entity/Q1521102 has no label
# entity http://www.wikidata.org/entity/Q16482238 has no label
# entity http://www.wikidata.org/entity/Q11787254 has no label
# entity http://www.wikidata.org/entity/Q19606369 has no label
# entity http://www.wikidata.org/entity/Q3286482 has no label
# entity http://www.wikidata.org/entity/Q106214766 has no label
# entity http://www.wikidata.org/entity/Q8247157 has no label
# entity http://www.wikidata.org/entity/Q86725850 has no label
# entity http://www.wikidata.org/entity/Q104128803 has no label
# entity http://www.wikidata.org/entity/Q21872265 has no label
# entity http://www.wikidata.org/entity/Q30119440 has no label
# entity http://www.wikidata.org/entity/Q8247157 has no label
# entity http://www.wikidata.org/entity/Q65092802 has no label
# entity http://www.wikidata.org/entity/Q873894 has no label
# entity http://www.wikidata.org/entity/Q3234830 has no label
# entity http://www.wikidata.org/entity/Q3847065 has no label
# entity http://www.wikidata.org/entity/Q1533391 has no label
# entity http://www.wikidata.org/entity/Q42324908 has no label
# entity http://www.wikidata.org/entity/Q101048596 has no label
# entity http://www.wikidata.org/entity/Q85191737 has no label
# entity http://www.wikidata.org/entity/Q101225951 has no label
# entity http://www.wikidata.org/entity/Q11519254 has no label
# entity http://www.wikidata.org/entity/Q28974159 has no label
# entity http://www.wikidata.org/entity/Q105724040 has no label
# entity http://www.wikidata.org/entity/Q9359968 has no label
# entity http://www.wikidata.org/entity/Q13446439 has no label
# entity http://www.wikidata.org/entity/Q1533391 has no label
# entity http://www.wikidata.org/entity/Q103831089 has no label
# entity http://www.wikidata.org/entity/Q106118619 has no label
# entity http://www.wikidata.org/entity/Q105581951 has no label
# entity http://www.wikidata.org/entity/Q20899933 has no label
# entity http://www.wikidata.org/entity/Q107093106 has no label
# entity http://www.wikidata.org/entity/Q16621687 has no label
# entity http://www.wikidata.org/entity/Q11478170 has no label
# entity http://www.wikidata.org/entity/Q86725850 has no label
# entity http://www.wikidata.org/entity/Q64908149 has no label
# entity http://www.wikidata.org/entity/Q57900611 has no label
# entity http://www.wikidata.org/entity/Q4123503 has no label
# entity http://www.wikidata.org/entity/Q78350090 has no label
# entity http://www.wikidata.org/entity/Q30119440 has no label
# entity http://www.wikidata.org/entity/Q3442202 has no label
# entity http://www.wikidata.org/entity/Q21127435 has no label
# entity http://www.wikidata.org/entity/Q4204698 has no label
# entity http://www.wikidata.org/entity/Q4009790 has no label
# entity http://www.wikidata.org/entity/Q3223380 has no label
# entity http://www.wikidata.org/entity/Q2845464 has no label
# entity http://www.wikidata.org/entity/Q3394364 has no label
# entity http://www.wikidata.org/entity/Q25439924 has no label
# entity http://www.wikidata.org/entity/Q102346387 has no label
# entity http://www.wikidata.org/entity/Q71150300 has no label
# entity http://www.wikidata.org/entity/Q18405973 has no label
# entity http://www.wikidata.org/entity/Q18697224 has no label
# entity http://www.wikidata.org/entity/Q22666689 has no label
# entity http://www.wikidata.org/entity/Q12301703 has no label
# entity http://www.wikidata.org/entity/Q10545447 has no label
# entity http://www.wikidata.org/entity/Q1192986 has no label
# entity http://www.wikidata.org/entity/Q1430095 has no label
# entity http://www.wikidata.org/entity/Q84181198 has no label
# entity http://www.wikidata.org/entity/Q1299062 has no label
# entity http://www.wikidata.org/entity/Q15178956 has no label
# entity http://www.wikidata.org/entity/Q5360167 has no label
# entity http://www.wikidata.org/entity/Q18384665 has no label
# entity http://www.wikidata.org/entity/Q3208072 has no label
# entity http://www.wikidata.org/entity/Q105642651 has no label
# entity http://www.wikidata.org/entity/Q49322720 has no label
# entity http://www.wikidata.org/entity/Q56312224 has no label
# entity http://www.wikidata.org/entity/Q101245161 has no label
# entity http://www.wikidata.org/entity/Q55598789 has no label
# entity http://www.wikidata.org/entity/Q4310784 has no label
# entity http://www.wikidata.org/entity/Q65092158 has no label
# entity http://www.wikidata.org/entity/Q98457067 has no label
# entity http://www.wikidata.org/entity/Q1192986 has no label
# entity http://www.wikidata.org/entity/Q104128417 has no label
# entity http://www.wikidata.org/entity/Q12100227 has no label
# entity http://www.wikidata.org/entity/Q5780686 has no label
# entity http://www.wikidata.org/entity/Q4467556 has no label
# entity http://www.wikidata.org/entity/Q5690317 has no label
# entity http://www.wikidata.org/entity/Q11988061 has no label
# entity http://www.wikidata.org/entity/Q3285347 has no label
# entity http://www.wikidata.org/entity/Q1131926 has no label
# entity http://www.wikidata.org/entity/Q50491222 has no label
# entity http://www.wikidata.org/entity/Q60988243 has no label
# entity http://www.wikidata.org/entity/Q2305489 has no label
# entity http://www.wikidata.org/entity/Q5690317 has no label
# entity http://www.wikidata.org/entity/Q5980862 has no label
# entity http://www.wikidata.org/entity/Q55596753 has no label
# entity http://www.wikidata.org/entity/Q55598789 has no label
# entity http://www.wikidata.org/entity/Q4197865 has no label
# entity http://www.wikidata.org/entity/Q873894 has no label
# entity http://www.wikidata.org/entity/Q47500835 has no label
# entity http://www.wikidata.org/entity/Q3823840 has no label
# entity http://www.wikidata.org/entity/Q16332388 has no label
# entity http://www.wikidata.org/entity/Q9004350 has no label
# entity http://www.wikidata.org/entity/Q4041750 has no label
# entity http://www.wikidata.org/entity/Q28749716 has no label
# entity http://www.wikidata.org/entity/Q56479557 has no label
# entity http://www.wikidata.org/entity/Q3661476 has no label
# entity http://www.wikidata.org/entity/Q87725165 has no label
# entity http://www.wikidata.org/entity/Q102914067 has no label
# entity http://www.wikidata.org/entity/Q3894686 has no label
# entity http://www.wikidata.org/entity/Q28749716 has no label
# entity http://www.wikidata.org/entity/Q17231050 has no label
# entity http://www.wikidata.org/entity/Q65860636 has no label
# entity http://www.wikidata.org/entity/Q21872265 has no label
# entity http://www.wikidata.org/entity/Q61697217 has no label
# entity http://www.wikidata.org/entity/Q20817092 has no label
# entity http://www.wikidata.org/entity/Q786133 has no label
# entity http://www.wikidata.org/entity/Q12034863 has no label
# entity http://www.wikidata.org/entity/Q101246790 has no label
# entity http://www.wikidata.org/entity/Q8774107 has no label
# entity http://www.wikidata.org/entity/Q11784265 has no label
# entity http://www.wikidata.org/entity/Q92111918 has no label
# entity http://www.wikidata.org/entity/Q107294704 has no label
# entity http://www.wikidata.org/entity/Q20729380 has no label
# entity http://www.wikidata.org/entity/Q19376660 has no label
# entity http://www.wikidata.org/entity/Q12151361 has no label
# entity http://www.wikidata.org/entity/Q11335240 has no label
# entity http://www.wikidata.org/entity/Q21938020 has no label
# entity http://www.wikidata.org/entity/Q9359968 has no label
# entity http://www.wikidata.org/entity/Q3958932 has no label
# entity http://www.wikidata.org/entity/Q64976189 has no label
# entity http://www.wikidata.org/entity/Q102350415 has no label
# entity http://www.wikidata.org/entity/Q52156385 has no label
# entity http://www.wikidata.org/entity/Q10817484 has no label
# entity http://www.wikidata.org/entity/Q101049557 has no label
# entity http://www.wikidata.org/entity/Q106159919 has no label
# entity http://www.wikidata.org/entity/Q103828596 has no label
# entity http://www.wikidata.org/entity/Q99641832 has no label
# entity http://www.wikidata.org/entity/Q47885100 has no label
# entity http://www.wikidata.org/entity/Q11781176 has no label
# entity http://www.wikidata.org/entity/Q103830965 has no label
# entity http://www.wikidata.org/entity/Q12747927 has no label
# entity http://www.wikidata.org/entity/Q104640367 has no label
# entity http://www.wikidata.org/entity/Q13012765 has no label
# entity http://www.wikidata.org/entity/Q84181198 has no label
# entity http://www.wikidata.org/entity/Q16084429 has no label
# entity http://www.wikidata.org/entity/Q55597835 has no label
# entity http://www.wikidata.org/entity/Q3208072 has no label
# entity http://www.wikidata.org/entity/Q28563829 has no label
# entity http://www.wikidata.org/entity/Q102427883 has no label
# entity http://www.wikidata.org/entity/Q5360167 has no label
# entity http://www.wikidata.org/entity/Q105452943 has no label
# entity http://www.wikidata.org/entity/Q78350090 has no label
# entity http://www.wikidata.org/entity/Q17263964 has no label
# entity http://www.wikidata.org/entity/Q949683 has no label
# entity http://www.wikidata.org/entity/Q85191737 has no label
# entity http://www.wikidata.org/entity/Q17176148 has no label
# entity http://www.wikidata.org/entity/Q107324429 has no label
# entity http://www.wikidata.org/entity/Q20502987 has no label
# entity http://www.wikidata.org/entity/Q30119440 has no label
# entity http://www.wikidata.org/entity/Q42324974 has no label
# entity http://www.wikidata.org/entity/Q3211223 has no label
# entity http://www.wikidata.org/entity/Q20493926 has no label
# entity http://www.wikidata.org/entity/Q3532775 has no label
# entity http://www.wikidata.org/entity/Q6359231 has no label
# entity http://www.wikidata.org/entity/Q10822396 has no label
# entity http://www.wikidata.org/entity/Q74252500 has no label
# entity http://www.wikidata.org/entity/Q3406422 has no label
# entity http://www.wikidata.org/entity/Q99328660 has no label
# entity http://www.wikidata.org/entity/Q106466938 has no label
# entity http://www.wikidata.org/entity/Q3330580 has no label
# entity http://www.wikidata.org/entity/Q104599108 has no label
# entity http://www.wikidata.org/entity/Q3793101 has no label
# entity http://www.wikidata.org/entity/Q20756664 has no label
# entity http://www.wikidata.org/entity/Q64976084 has no label
# entity http://www.wikidata.org/entity/Q50212272 has no label
# entity http://www.wikidata.org/entity/Q2432232 has no label
# entity http://www.wikidata.org/entity/Q102361514 has no label
# entity http://www.wikidata.org/entity/Q3462571 has no label
# entity http://www.wikidata.org/entity/Q3208072 has no label
# entity http://www.wikidata.org/entity/Q101048596 has no label
# entity http://www.wikidata.org/entity/Q4527612 has no label
# entity http://www.wikidata.org/entity/Q5864214 has no label
# entity http://www.wikidata.org/entity/Q101082381 has no label
# entity http://www.wikidata.org/entity/Q20495360 has no label
# entity http://www.wikidata.org/entity/Q106150038 has no label
# entity http://www.wikidata.org/entity/Q2688886 has no label
# entity http://www.wikidata.org/entity/Q3233349 has no label
# entity http://www.wikidata.org/entity/Q12175136 has no label
# entity http://www.wikidata.org/entity/Q3147722 has no label
# entity http://www.wikidata.org/entity/Q19275033 has no label
# entity http://www.wikidata.org/entity/Q42224649 has no label
# entity http://www.wikidata.org/entity/Q18180858 has no label
# entity http://www.wikidata.org/entity/Q3223978 has no label
# entity http://www.wikidata.org/entity/Q103825861 has no label
# entity http://www.wikidata.org/entity/Q4374999 has no label
# entity http://www.wikidata.org/entity/Q106159919 has no label
# entity http://www.wikidata.org/entity/Q86469496 has no label
# entity http://www.wikidata.org/entity/Q12100227 has no label
# entity http://www.wikidata.org/entity/Q86725850 has no label
# entity http://www.wikidata.org/entity/Q6048077 has no label
# entity http://www.wikidata.org/entity/Q98457067 has no label
# entity http://www.wikidata.org/entity/Q100293464 has no label
# entity http://www.wikidata.org/entity/Q21334186 has no label
# entity http://www.wikidata.org/entity/Q102428550 has no label
# entity http://www.wikidata.org/entity/Q3413908 has no label
# entity http://www.wikidata.org/entity/Q18003129 has no label
# entity http://www.wikidata.org/entity/Q52834286 has no label
# entity http://www.wikidata.org/entity/Q1965615 has no label
# entity http://www.wikidata.org/entity/Q30119440 has no label
# entity http://www.wikidata.org/entity/Q31282601 has no label
# entity http://www.wikidata.org/entity/Q15154773 has no label
# entity http://www.wikidata.org/entity/Q2305371 has no label
# entity http://www.wikidata.org/entity/Q96755095 has no label
# entity http://www.wikidata.org/entity/Q9132699 has no label
# entity http://www.wikidata.org/entity/Q6172300 has no label
# entity http://www.wikidata.org/entity/Q106128762 has no label
# entity http://www.wikidata.org/entity/Q15849464 has no label
# entity http://www.wikidata.org/entity/Q16084429 has no label
# entity http://www.wikidata.org/entity/Q65092084 has no label
# entity http://www.wikidata.org/entity/Q20493926 has no label
# entity http://www.wikidata.org/entity/Q3548664 has no label
# entity http://www.wikidata.org/entity/Q106158648 has no label
# entity http://www.wikidata.org/entity/Q55596753 has no label
# entity http://www.wikidata.org/entity/Q18384665 has no label
# entity http://www.wikidata.org/entity/Q19516219 has no label
# entity http://www.wikidata.org/entity/Q13022075 has no label
# entity http://www.wikidata.org/entity/Q5869412 has no label
# entity http://www.wikidata.org/entity/Q76962224 has no label
# entity http://www.wikidata.org/entity/Q2313910 has no label
# entity http://www.wikidata.org/entity/Q1131926 has no label
# entity http://www.wikidata.org/entity/Q105581951 has no label
# entity http://www.wikidata.org/entity/Q25439924 has no label
# entity http://www.wikidata.org/entity/Q105724040 has no label
# entity http://www.wikidata.org/entity/Q102315029 has no label
# entity http://www.wikidata.org/entity/Q83721641 has no label
# entity http://www.wikidata.org/entity/Q16141765 has no label
# entity http://www.wikidata.org/entity/Q4197865 has no label
# entity http://www.wikidata.org/entity/Q17994554 has no label
# entity http://www.wikidata.org/entity/Q20817092 has no label
# entity http://www.wikidata.org/entity/Q9372927 has no label
# entity http://www.wikidata.org/entity/Q3226052 has no label
# entity http://www.wikidata.org/entity/Q64995140 has no label
# entity http://www.wikidata.org/entity/Q96755095 has no label
# entity http://www.wikidata.org/entity/Q21006435 has no label
# entity http://www.wikidata.org/entity/Q9097951 has no label
# entity http://www.wikidata.org/entity/Q23827934 has no label
# entity http://www.wikidata.org/entity/Q18405973 has no label
# entity http://www.wikidata.org/entity/Q22098468 has no label
# entity http://www.wikidata.org/entity/Q101620888 has no label
# entity http://www.wikidata.org/entity/Q10885793 has no label
# entity http://www.wikidata.org/entity/Q104641594 has no label
# entity http://www.wikidata.org/entity/Q20001157 has no label
# entity http://www.wikidata.org/entity/Q86725944 has no label
# entity http://www.wikidata.org/entity/Q18697224 has no label
# entity http://www.wikidata.org/entity/Q8774107 has no label
# entity http://www.wikidata.org/entity/Q16938163 has no label
# entity http://www.wikidata.org/entity/Q52834286 has no label
# entity http://www.wikidata.org/entity/Q28811000 has no label
# entity http://www.wikidata.org/entity/Q102349756 has no label
# entity http://www.wikidata.org/entity/Q6053638 has no label
# entity http://www.wikidata.org/entity/Q9217338 has no label
# entity http://www.wikidata.org/entity/Q80482102 has no label
# entity http://www.wikidata.org/entity/Q18291034 has no label
# entity http://www.wikidata.org/entity/Q106925827 has no label
# entity http://www.wikidata.org/entity/Q52834286 has no label
# entity http://www.wikidata.org/entity/Q65589430 has no label
# entity http://www.wikidata.org/entity/Q10260523 has no label
# entity http://www.wikidata.org/entity/Q17682995 has no label
# entity http://www.wikidata.org/entity/Q105581951 has no label
# entity http://www.wikidata.org/entity/Q5980862 has no label
# entity http://www.wikidata.org/entity/Q97210756 has no label
# entity http://www.wikidata.org/entity/Q22671137 has no label
# entity http://www.wikidata.org/entity/Q11988061 has no label
# entity http://www.wikidata.org/entity/Q25439924 has no label
# entity http://www.wikidata.org/entity/Q15221756 has no label
# entity http://www.wikidata.org/entity/Q104590838 has no label
# entity http://www.wikidata.org/entity/Q1204829 has no label
# entity http://www.wikidata.org/entity/Q104591082 has no label
# entity http://www.wikidata.org/entity/Q18760491 has no label
# entity http://www.wikidata.org/entity/Q2096409 has no label
# entity http://www.wikidata.org/entity/Q106150038 has no label
# entity http://www.wikidata.org/entity/Q104128812 has no label
# entity http://www.wikidata.org/entity/Q69421673 has no label
# entity http://www.wikidata.org/entity/Q33103003 has no label
# entity http://www.wikidata.org/entity/Q55598789 has no label
# entity http://www.wikidata.org/entity/Q15849464 has no label
# entity http://www.wikidata.org/entity/Q16141765 has no label
# entity http://www.wikidata.org/entity/Q102362894 has no label
# entity http://www.wikidata.org/entity/Q16141765 has no label
# entity http://www.wikidata.org/entity/Q101787909 has no label
# entity http://www.wikidata.org/entity/Q21074586 has no label
# entity http://www.wikidata.org/entity/Q3594820 has no label
# entity http://www.wikidata.org/entity/Q20001157 has no label
# entity http://www.wikidata.org/entity/Q4374999 has no label
# entity http://www.wikidata.org/entity/Q86427065 has no label
# entity http://www.wikidata.org/entity/Q3147722 has no label
# entity http://www.wikidata.org/entity/Q12624090 has no label
# entity http://www.wikidata.org/entity/Q103037616 has no label
# entity http://www.wikidata.org/entity/Q10822396 has no label
# entity http://www.wikidata.org/entity/Q6172300 has no label
# entity http://www.wikidata.org/entity/Q106158465 has no label
# entity http://www.wikidata.org/entity/Q47516526 has no label
# entity http://www.wikidata.org/entity/Q16591983 has no label
# entity http://www.wikidata.org/entity/Q17335558 has no label
# entity http://www.wikidata.org/entity/Q106473918 has no label
# entity http://www.wikidata.org/entity/Q20181396 has no label
# entity http://www.wikidata.org/entity/Q99328660 has no label
# entity http://www.wikidata.org/entity/Q106473747 has no label
# entity http://www.wikidata.org/entity/Q3209750 has no label
# entity http://www.wikidata.org/entity/Q18203684 has no label
# entity http://www.wikidata.org/entity/Q99481375 has no label
# entity http://www.wikidata.org/entity/Q18003150 has no label
# entity http://www.wikidata.org/entity/Q11506265 has no label
# entity http://www.wikidata.org/entity/Q4060426 has no label
# entity http://www.wikidata.org/entity/Q20580507 has no label
# entity http://www.wikidata.org/entity/Q11318535 has no label
# entity http://www.wikidata.org/entity/Q100977861 has no label
# entity http://www.wikidata.org/entity/Q16141765 has no label
# entity http://www.wikidata.org/entity/Q5963194 has no label
# entity http://www.wikidata.org/entity/Q1521102 has no label
# entity http://www.wikidata.org/entity/Q29577770 has no label
# entity http://www.wikidata.org/entity/Q1212172 has no label
# entity http://www.wikidata.org/entity/Q3576574 has no label
# entity http://www.wikidata.org/entity/Q100293423 has no label
# entity http://www.wikidata.org/entity/Q1965615 has no label
# entity http://www.wikidata.org/entity/Q93496819 has no label
# entity http://www.wikidata.org/entity/Q6172300 has no label
# entity http://www.wikidata.org/entity/Q5856317 has no label
# entity http://www.wikidata.org/entity/Q33126631 has no label
# entity http://www.wikidata.org/entity/Q33103003 has no label
# entity http://www.wikidata.org/entity/Q10264592 has no label
# entity http://www.wikidata.org/entity/Q6069557 has no label
# entity http://www.wikidata.org/entity/Q64995140 has no label
# entity http://www.wikidata.org/entity/Q106571575 has no label
# entity http://www.wikidata.org/entity/Q101588992 has no label
# entity http://www.wikidata.org/entity/Q101048596 has no label
# entity http://www.wikidata.org/entity/Q87725513 has no label
# entity http://www.wikidata.org/entity/Q21655332 has no label
# entity http://www.wikidata.org/entity/Q16938162 has no label
# entity http://www.wikidata.org/entity/Q102802045 has no label
# entity http://www.wikidata.org/entity/Q6359231 has no label
# entity http://www.wikidata.org/entity/Q19275033 has no label
# entity http://www.wikidata.org/entity/Q104583209 has no label
# entity http://www.wikidata.org/entity/Q104591076 has no label
# entity http://www.wikidata.org/entity/Q18405973 has no label
# entity http://www.wikidata.org/entity/Q75762777 has no label
# entity http://www.wikidata.org/entity/Q104591082 has no label
# entity http://www.wikidata.org/entity/Q5864214 has no label
# entity http://www.wikidata.org/entity/Q537095 has no label
# entity http://www.wikidata.org/entity/Q30119440 has no label
# entity http://www.wikidata.org/entity/Q8247157 has no label
# entity http://www.wikidata.org/entity/Q5748759 has no label
# entity http://www.wikidata.org/entity/Q13446439 has no label
# entity http://www.wikidata.org/entity/Q18291034 has no label
# entity http://www.wikidata.org/entity/Q102797257 has no label
# entity http://www.wikidata.org/entity/Q3069871 has no label
# entity http://www.wikidata.org/entity/Q13446439 has no label
# entity http://www.wikidata.org/entity/Q10822396 has no label
# entity http://www.wikidata.org/entity/Q20098283 has no label
# entity http://www.wikidata.org/entity/Q50491647 has no label
# entity http://www.wikidata.org/entity/Q13571661 has no label
# entity http://www.wikidata.org/entity/Q6172300 has no label
# entity http://www.wikidata.org/entity/Q5690317 has no label
# entity http://www.wikidata.org/entity/Q10822396 has no label
# entity http://www.wikidata.org/entity/Q20729380 has no label
# entity http://www.wikidata.org/entity/Q1430095 has no label
# entity http://www.wikidata.org/entity/Q98708518 has no label
# entity http://www.wikidata.org/entity/Q2096409 has no label
# entity http://www.wikidata.org/entity/Q18291034 has no label
# entity http://www.wikidata.org/entity/Q86504398 has no label
# entity http://www.wikidata.org/entity/Q30119440 has no label
# entity http://www.wikidata.org/entity/Q28668250 has no label
# entity http://www.wikidata.org/entity/Q102346114 has no label
# entity http://www.wikidata.org/entity/Q11784265 has no label
# entity http://www.wikidata.org/entity/Q15221756 has no label
# entity http://www.wikidata.org/entity/Q3393193 has no label
# entity http://www.wikidata.org/entity/Q71150300 has no label
# entity http://www.wikidata.org/entity/Q1535471 has no label
# entity http://www.wikidata.org/entity/Q107519640 has no label
# entity http://www.wikidata.org/entity/Q12100227 has no label
# entity http://www.wikidata.org/entity/Q100977063 has no label
# entity http://www.wikidata.org/entity/Q11698830 has no label
# entity http://www.wikidata.org/entity/Q12005276 has no label
# entity http://www.wikidata.org/entity/Q10517907 has no label
# entity http://www.wikidata.org/entity/Q20729380 has no label
# entity http://www.wikidata.org/entity/Q22246810 has no label
# entity http://www.wikidata.org/entity/Q4024101 has no label
# entity http://www.wikidata.org/entity/Q84181198 has no label
# entity http://www.wikidata.org/entity/Q2454505 has no label
# entity http://www.wikidata.org/entity/Q873894 has no label
# entity http://www.wikidata.org/entity/Q55598789 has no label
# entity http://www.wikidata.org/entity/Q11522520 has no label
# entity http://www.wikidata.org/entity/Q3532775 has no label
# entity http://www.wikidata.org/entity/Q5977349 has no label
# entity http://www.wikidata.org/entity/Q107444217 has no label
# entity http://www.wikidata.org/entity/Q3234830 has no label
# entity http://www.wikidata.org/entity/Q1533391 has no label
# entity http://www.wikidata.org/entity/Q5748759 has no label
# entity http://www.wikidata.org/entity/Q4099138 has no label
# entity http://www.wikidata.org/entity/Q3823840 has no label
# entity http://www.wikidata.org/entity/Q10503785 has no label
# entity http://www.wikidata.org/entity/Q12100227 has no label
# entity http://www.wikidata.org/entity/Q104128680 has no label
# entity http://www.wikidata.org/entity/Q104640564 has no label
# entity http://www.wikidata.org/entity/Q50573475 has no label
# entity http://www.wikidata.org/entity/Q103831089 has no label
# entity http://www.wikidata.org/entity/Q55596753 has no label
# entity http://www.wikidata.org/entity/Q50357191 has no label
# entity http://www.wikidata.org/entity/Q26877882 has no label
# entity http://www.wikidata.org/entity/Q16490547 has no label
# entity http://www.wikidata.org/entity/Q1741934 has no label
# entity http://www.wikidata.org/entity/Q21007188 has no label
# entity http://www.wikidata.org/entity/Q5864214 has no label
# entity http://www.wikidata.org/entity/Q27043038 has no label
# entity http://www.wikidata.org/entity/Q104128680 has no label
# entity http://www.wikidata.org/entity/Q3233349 has no label
# entity http://www.wikidata.org/entity/Q30942216 has no label
# entity http://www.wikidata.org/entity/Q63107671 has no label
# entity http://www.wikidata.org/entity/Q30119440 has no label
# entity http://www.wikidata.org/entity/Q6457684 has no label
# entity http://www.wikidata.org/entity/Q4197865 has no label
# entity http://www.wikidata.org/entity/Q3224036 has no label
# entity http://www.wikidata.org/entity/Q86504398 has no label
# entity http://www.wikidata.org/entity/Q69032012 has no label
# entity http://www.wikidata.org/entity/Q2865432 has no label
# entity http://www.wikidata.org/entity/Q106118619 has no label
# entity http://www.wikidata.org/entity/Q50357191 has no label
# entity http://www.wikidata.org/entity/Q1969749 has no label
# entity http://www.wikidata.org/entity/Q3802164 has no label
# entity http://www.wikidata.org/entity/Q3224036 has no label
# entity http://www.wikidata.org/entity/Q106214876 has no label
# entity http://www.wikidata.org/entity/Q3793101 has no label
# entity http://www.wikidata.org/entity/Q16482238 has no label
# entity http://www.wikidata.org/entity/Q30119440 has no label
# entity http://www.wikidata.org/entity/Q84181198 has no label
# entity http://www.wikidata.org/entity/Q4029764 has no label
# entity http://www.wikidata.org/entity/Q15849464 has no label
# entity http://www.wikidata.org/entity/Q78350090 has no label
# entity http://www.wikidata.org/entity/Q16141765 has no label
# entity http://www.wikidata.org/entity/Q18088924 has no label
# entity http://www.wikidata.org/entity/Q101043740 has no label
# entity http://www.wikidata.org/entity/Q10374256 has no label
# entity http://www.wikidata.org/entity/Q16305292 has no label
# entity http://www.wikidata.org/entity/Q41695165 has no label
# entity http://www.wikidata.org/entity/Q42324963 has no label
# entity http://www.wikidata.org/entity/Q28494629 has no label
# entity http://www.wikidata.org/entity/Q16262597 has no label
# entity http://www.wikidata.org/entity/Q1912949 has no label
# entity http://www.wikidata.org/entity/Q10381481 has no label
# entity http://www.wikidata.org/entity/Q18697224 has no label
# entity http://www.wikidata.org/entity/Q18003142 has no label
# entity http://www.wikidata.org/entity/Q15849464 has no label
# entity http://www.wikidata.org/entity/Q21007188 has no label
# entity http://www.wikidata.org/entity/Q103831089 has no label
# entity http://www.wikidata.org/entity/Q100966707 has no label
# entity http://www.wikidata.org/entity/Q4197865 has no label
# entity http://www.wikidata.org/entity/Q3405570 has no label
# entity http://www.wikidata.org/entity/Q101245556 has no label
# entity http://www.wikidata.org/entity/Q11894985 has no label
# entity http://www.wikidata.org/entity/Q105642651 has no label
# entity http://www.wikidata.org/entity/Q16938163 has no label
# entity http://www.wikidata.org/entity/Q30119440 has no label
# entity http://www.wikidata.org/entity/Q7218083 has no label
# entity http://www.wikidata.org/entity/Q13022075 has no label
# entity http://www.wikidata.org/entity/Q5770883 has no label
# entity http://www.wikidata.org/entity/Q3820690 has no label
# entity http://www.wikidata.org/entity/Q20636406 has no label
# entity http://www.wikidata.org/entity/Q105581951 has no label
# entity http://www.wikidata.org/entity/Q12100227 has no label
# entity http://www.wikidata.org/entity/Q26877871 has no label
# entity http://www.wikidata.org/entity/Q55596753 has no label
# entity http://www.wikidata.org/entity/Q106127757 has no label
# entity http://www.wikidata.org/entity/Q102350582 has no label
# entity http://www.wikidata.org/entity/Q5748759 has no label
# entity http://www.wikidata.org/entity/Q64691801 has no label
# entity http://www.wikidata.org/entity/Q104128417 has no label
# entity http://www.wikidata.org/entity/Q10822396 has no label
# entity http://www.wikidata.org/entity/Q16141765 has no label
# entity http://www.wikidata.org/entity/Q3703448 has no label
# entity http://www.wikidata.org/entity/Q6005514 has no label
# entity http://www.wikidata.org/entity/Q11597326 has no label
# entity http://www.wikidata.org/entity/Q3575712 has no label
# entity http://www.wikidata.org/entity/Q26834048 has no label
# entity http://www.wikidata.org/entity/Q14756244 has no label
# entity http://www.wikidata.org/entity/Q2434385 has no label
# entity http://www.wikidata.org/entity/Q3532775 has no label
# entity http://www.wikidata.org/entity/Q5645791 has no label
# entity http://www.wikidata.org/entity/Q99982964 has no label
# entity http://www.wikidata.org/entity/Q102361201 has no label
# entity http://www.wikidata.org/entity/Q28974159 has no label
# entity http://www.wikidata.org/entity/Q3147722 has no label
# entity http://www.wikidata.org/entity/Q106215281 has no label
# entity http://www.wikidata.org/entity/Q15849464 has no label
# entity http://www.wikidata.org/entity/Q3212518 has no label
# entity http://www.wikidata.org/entity/Q28690252 has no label
# entity http://www.wikidata.org/entity/Q2454505 has no label
# entity http://www.wikidata.org/entity/Q5360167 has no label
# entity http://www.wikidata.org/entity/Q12321398 has no label
# entity http://www.wikidata.org/entity/Q64976169 has no label
# entity http://www.wikidata.org/entity/Q4527612 has no label
# entity http://www.wikidata.org/entity/Q64975500 has no label
# entity http://www.wikidata.org/entity/Q23827934 has no label
# entity http://www.wikidata.org/entity/Q19606369 has no label
# entity http://www.wikidata.org/entity/Q15849464 has no label
# entity http://www.wikidata.org/entity/Q12756132 has no label
# entity http://www.wikidata.org/entity/Q13446439 has no label
# ...
# entity http://www.wikidata.org/entity/Q106925685 has no label
# entity http://www.wikidata.org/entity/Q11784265 has no label
# entity http://www.wikidata.org/entity/Q104626163 has no label
# entity http://www.wikidata.org/entity/Q3821416 has no label
# entity http://www.wikidata.org/entity/Q20493926 has no label
# entity http://www.wikidata.org/entity/Q1965615 has no label
# entity http://www.wikidata.org/entity/Q101112643 has no label
# entity http://www.wikidata.org/entity/Q3225410 has no label
# entity http://www.wikidata.org/entity/Q20001157 has no label
# entity http://www.wikidata.org/entity/Q12612886 has no label
# entity http://www.wikidata.org/entity/Q56216438 has no label
# entity http://www.wikidata.org/entity/Q20636406 has no label
# entity http://www.wikidata.org/entity/Q11519254 has no label
# entity http://www.wikidata.org/entity/Q100966707 has no label
# entity http://www.wikidata.org/entity/Q105724040 has no label
# entity http://www.wikidata.org/entity/Q30119440 has no label
# entity http://www.wikidata.org/entity/Q12881956 has no label
# entity http://www.wikidata.org/entity/Q69032012 has no label
# entity http://www.wikidata.org/entity/Q65394309 has no label
# entity http://www.wikidata.org/entity/Q4100029 has no label
# entity http://www.wikidata.org/entity/Q3344337 has no label
# entity http://www.wikidata.org/entity/Q17979317 has no label
# entity http://www.wikidata.org/entity/Q95443712 has no label
# entity http://www.wikidata.org/entity/Q17231050 has no label
# entity http://www.wikidata.org/entity/Q30740620 has no label
# entity http://www.wikidata.org/entity/Q64976142 has no label
# entity http://www.wikidata.org/entity/Q2349685 has no label
# entity http://www.wikidata.org/entity/Q106127757 has no label
# entity http://www.wikidata.org/entity/Q13420990 has no label
# entity http://www.wikidata.org/entity/Q104640367 has no label
# entity http://www.wikidata.org/entity/Q4197865 has no label
# entity http://www.wikidata.org/entity/Q28974159 has no label
# entity http://www.wikidata.org/entity/Q71150300 has no label
# entity http://www.wikidata.org/entity/Q16421610 has no label
# entity http://www.wikidata.org/entity/Q8247157 has no label
# entity http://www.wikidata.org/entity/Q8247157 has no label
# entity http://www.wikidata.org/entity/Q25395640 has no label
# entity http://www.wikidata.org/entity/Q106269043 has no label
# entity http://www.wikidata.org/entity/Q5770883 has no label
# entity http://www.wikidata.org/entity/Q3212917 has no label
# entity http://www.wikidata.org/entity/Q60836615 has no label
# entity http://www.wikidata.org/entity/Q16651762 has no label
# entity http://www.wikidata.org/entity/Q19516219 has no label
# entity http://www.wikidata.org/entity/Q65092155 has no label
# entity http://www.wikidata.org/entity/Q17979323 has no label
# entity http://www.wikidata.org/entity/Q9000569 has no label
# entity http://www.wikidata.org/entity/Q106214645 has no label
# entity http://www.wikidata.org/entity/Q3575712 has no label
# entity http://www.wikidata.org/entity/Q3202081 has no label
# entity http://www.wikidata.org/entity/Q3234830 has no label
# entity http://www.wikidata.org/entity/Q22246810 has no label
# entity http://www.wikidata.org/entity/Q105581951 has no label
# entity http://www.wikidata.org/entity/Q103825861 has no label
# entity http://www.wikidata.org/entity/Q3233349 has no label
# entity http://www.wikidata.org/entity/Q32998742 has no label
# entity http://www.wikidata.org/entity/Q103037616 has no label
# entity http://www.wikidata.org/entity/Q106215281 has no label
# entity http://www.wikidata.org/entity/Q19507580 has no label
# entity http://www.wikidata.org/entity/Q5748759 has no label
# entity http://www.wikidata.org/entity/Q58420261 has no label
# entity http://www.wikidata.org/entity/Q24856559 has no label
# entity http://www.wikidata.org/entity/Q15927927 has no label
# entity http://www.wikidata.org/entity/Q13446439 has no label
# entity http://www.wikidata.org/entity/Q12100227 has no label
# entity http://www.wikidata.org/entity/Q102334558 has no label
# entity http://www.wikidata.org/entity/Q16141765 has no label
# entity http://www.wikidata.org/entity/Q18003149 has no label
# entity http://www.wikidata.org/entity/Q104640564 has no label
# entity http://www.wikidata.org/entity/Q13537170 has no label
# entity http://www.wikidata.org/entity/Q16745128 has no label
# entity http://www.wikidata.org/entity/Q1365619 has no label
# entity http://www.wikidata.org/entity/Q3950561 has no label
# entity http://www.wikidata.org/entity/Q12005276 has no label
# entity http://www.wikidata.org/entity/Q11519254 has no label
# entity http://www.wikidata.org/entity/Q86726413 has no label
# entity http://www.wikidata.org/entity/Q3233506 has no label
# entity http://www.wikidata.org/entity/Q60988243 has no label
# entity http://www.wikidata.org/entity/Q60334407 has no label
# entity http://www.wikidata.org/entity/Q102243682 has no label
# entity http://www.wikidata.org/entity/Q102428640 has no label
# entity http://www.wikidata.org/entity/Q106862484 has no label
# entity http://www.wikidata.org/entity/Q16938162 has no label
# entity http://www.wikidata.org/entity/Q4029764 has no label
# entity http://www.wikidata.org/entity/Q16602138 has no label
# entity http://www.wikidata.org/entity/Q11522520 has no label
# entity http://www.wikidata.org/entity/Q48758652 has no label
# entity http://www.wikidata.org/entity/Q16141765 has no label
# entity http://www.wikidata.org/entity/Q77307319 has no label
# entity http://www.wikidata.org/entity/Q3227598 has no label
# entity http://www.wikidata.org/entity/Q11573283 has no label
# entity http://www.wikidata.org/entity/Q106473918 has no label
# entity http://www.wikidata.org/entity/Q6359617 has no label
# entity http://www.wikidata.org/entity/Q2454505 has no label
# entity http://www.wikidata.org/entity/Q5690317 has no label
# entity http://www.wikidata.org/entity/Q12034863 has no label
# entity http://www.wikidata.org/entity/Q11426516 has no label
# entity http://www.wikidata.org/entity/Q18203684 has no label
# entity http://www.wikidata.org/entity/Q104590755 has no label
# entity http://www.wikidata.org/entity/Q21334186 has no label
# entity http://www.wikidata.org/entity/Q55597835 has no label
# entity http://www.wikidata.org/entity/Q11318535 has no label
# entity http://www.wikidata.org/entity/Q16141765 has no label
# entity http://www.wikidata.org/entity/Q2432232 has no label
# entity http://www.wikidata.org/entity/Q104591082 has no label
# entity http://www.wikidata.org/entity/Q103826622 has no label
# entity http://www.wikidata.org/entity/Q41695165 has no label
# entity http://www.wikidata.org/entity/Q1868958 has no label
# entity http://www.wikidata.org/entity/Q5360167 has no label
# entity http://www.wikidata.org/entity/Q4024101 has no label
# entity http://www.wikidata.org/entity/Q102350727 has no label
# entity http://www.wikidata.org/entity/Q12321398 has no label
# entity http://www.wikidata.org/entity/Q11798287 has no label
# entity http://www.wikidata.org/entity/Q26255765 has no label
# entity http://www.wikidata.org/entity/Q16009977 has no label
# entity http://www.wikidata.org/entity/Q6343185 has no label
# entity http://www.wikidata.org/entity/Q83715730 has no label
# entity http://www.wikidata.org/entity/Q65092045 has no label
# entity http://www.wikidata.org/entity/Q3351915 has no label
# entity http://www.wikidata.org/entity/Q100249577 has no label
# entity http://www.wikidata.org/entity/Q3208072 has no label
# entity http://www.wikidata.org/entity/Q93518336 has no label
# entity http://www.wikidata.org/entity/Q16938163 has no label
# entity http://www.wikidata.org/entity/Q8247157 has no label
# entity http://www.wikidata.org/entity/Q4467556 has no label
# entity http://www.wikidata.org/entity/Q75233694 has no label
# entity http://www.wikidata.org/entity/Q2865432 has no label
# entity http://www.wikidata.org/entity/Q102806011 has no label
# entity http://www.wikidata.org/entity/Q5748759 has no label
# entity http://www.wikidata.org/entity/Q33056968 has no label
# entity http://www.wikidata.org/entity/Q101620888 has no label
# entity http://www.wikidata.org/entity/Q30119440 has no label
# entity http://www.wikidata.org/entity/Q1800306 has no label
# entity http://www.wikidata.org/entity/Q102346310 has no label
# entity http://www.wikidata.org/entity/Q2454505 has no label
# entity http://www.wikidata.org/entity/Q3719898 has no label
# entity http://www.wikidata.org/entity/Q106840723 has no label
# entity http://www.wikidata.org/entity/Q104128803 has no label
# entity http://www.wikidata.org/entity/Q102428100 has no label
# entity http://www.wikidata.org/entity/Q102346237 has no label
# entity http://www.wikidata.org/entity/Q28974159 has no label
# entity http://www.wikidata.org/entity/Q3823840 has no label
# entity http://www.wikidata.org/entity/Q4526480 has no label
# entity http://www.wikidata.org/entity/Q2113260 has no label
# entity http://www.wikidata.org/entity/Q61971595 has no label
# entity http://www.wikidata.org/entity/Q10822396 has no label
# entity http://www.wikidata.org/entity/Q50573475 has no label
# entity http://www.wikidata.org/entity/Q106128636 has no label
# entity http://www.wikidata.org/entity/Q30119440 has no label
# entity http://www.wikidata.org/entity/Q10822396 has no label
# entity http://www.wikidata.org/entity/Q41695165 has no label
# entity http://www.wikidata.org/entity/Q21334186 has no label
# entity http://www.wikidata.org/entity/Q106982388 has no label
# entity http://www.wikidata.org/entity/Q106150094 has no label
# entity http://www.wikidata.org/entity/Q5980862 has no label
# entity http://www.wikidata.org/entity/Q17053540 has no label
# entity http://www.wikidata.org/entity/Q622527 has no label
# entity http://www.wikidata.org/entity/Q5770883 has no label
# entity http://www.wikidata.org/entity/Q78350090 has no label
# entity http://www.wikidata.org/entity/Q30119440 has no label
# entity http://www.wikidata.org/entity/Q17682995 has no label
# entity http://www.wikidata.org/entity/Q61623104 has no label
# entity http://www.wikidata.org/entity/Q104853611 has no label
# entity http://www.wikidata.org/entity/Q15922702 has no label
# entity http://www.wikidata.org/entity/Q14756244 has no label
# entity http://www.wikidata.org/entity/Q13013801 has no label
# entity http://www.wikidata.org/entity/Q1212172 has no label
# entity http://www.wikidata.org/entity/Q2688886 has no label
# entity http://www.wikidata.org/entity/Q106149953 has no label
# entity http://www.wikidata.org/entity/Q20817092 has no label
# entity http://www.wikidata.org/entity/Q61971595 has no label
# entity http://www.wikidata.org/entity/Q105162103 has no label
# entity http://www.wikidata.org/entity/Q22098468 has no label
# entity http://www.wikidata.org/entity/Q14509108 has no label
# entity http://www.wikidata.org/entity/Q4526480 has no label
# entity http://www.wikidata.org/entity/Q105452943 has no label
# entity http://www.wikidata.org/entity/Q3624680 has no label
# entity http://www.wikidata.org/entity/Q1026994 has no label
# entity http://www.wikidata.org/entity/Q7218083 has no label
# entity http://www.wikidata.org/entity/Q55596753 has no label
# entity http://www.wikidata.org/entity/Q17349313 has no label
# entity http://www.wikidata.org/entity/Q65860636 has no label
# entity http://www.wikidata.org/entity/Q102909795 has no label
# entity http://www.wikidata.org/entity/Q16745128 has no label
# entity http://www.wikidata.org/entity/Q1239837 has no label
# entity http://www.wikidata.org/entity/Q4426552 has no label
# entity http://www.wikidata.org/entity/Q6359617 has no label
# entity http://www.wikidata.org/entity/Q19530268 has no label
# entity http://www.wikidata.org/entity/Q104128616 has no label
# entity http://www.wikidata.org/entity/Q3227598 has no label
# entity http://www.wikidata.org/entity/Q4197865 has no label
# entity http://www.wikidata.org/entity/Q8774107 has no label
# entity http://www.wikidata.org/entity/Q3719898 has no label
# entity http://www.wikidata.org/entity/Q9359968 has no label
# entity http://www.wikidata.org/entity/Q16906706 has no label
# entity http://www.wikidata.org/entity/Q106211445 has no label
# entity http://www.wikidata.org/entity/Q3661476 has no label
# entity http://www.wikidata.org/entity/Q17979323 has no label
# entity http://www.wikidata.org/entity/Q6048077 has no label
# entity http://www.wikidata.org/entity/Q11658241 has no label
# entity http://www.wikidata.org/entity/Q4197865 has no label
# entity http://www.wikidata.org/entity/Q1969749 has no label
# entity http://www.wikidata.org/entity/Q64396778 has no label
# entity http://www.wikidata.org/entity/Q22671137 has no label
# entity http://www.wikidata.org/entity/Q5770883 has no label
# entity http://www.wikidata.org/entity/Q15849464 has no label
# entity http://www.wikidata.org/entity/Q102362046 has no label
# entity http://www.wikidata.org/entity/Q106466938 has no label
# entity http://www.wikidata.org/entity/Q12768321 has no label
# entity http://www.wikidata.org/entity/Q18697224 has no label
# entity http://www.wikidata.org/entity/Q103468547 has no label
# entity http://www.wikidata.org/entity/Q1533391 has no label
# entity http://www.wikidata.org/entity/Q33103003 has no label
# entity http://www.wikidata.org/entity/Q102346237 has no label
# entity http://www.wikidata.org/entity/Q76962224 has no label
# entity http://www.wikidata.org/entity/Q65092141 has no label
# entity http://www.wikidata.org/entity/Q1473284 has no label
# entity http://www.wikidata.org/entity/Q13446439 has no label
# entity http://www.wikidata.org/entity/Q19637350 has no label
# entity http://www.wikidata.org/entity/Q4197865 has no label
# entity http://www.wikidata.org/entity/Q30740620 has no label
# entity http://www.wikidata.org/entity/Q17176148 has no label
# entity http://www.wikidata.org/entity/Q55596753 has no label
# entity http://www.wikidata.org/entity/Q3823840 has no label
# entity http://www.wikidata.org/entity/Q19470880 has no label
# entity http://www.wikidata.org/entity/Q64691801 has no label
# entity http://www.wikidata.org/entity/Q31689823 has no label
# entity http://www.wikidata.org/entity/Q102910457 has no label
# entity http://www.wikidata.org/entity/Q101049393 has no label
# entity http://www.wikidata.org/entity/Q5780686 has no label
# entity http://www.wikidata.org/entity/Q19516219 has no label
# entity http://www.wikidata.org/entity/Q41695165 has no label
# entity http://www.wikidata.org/entity/Q55508943 has no label
# entity http://www.wikidata.org/entity/Q13024385 has no label
# entity http://www.wikidata.org/entity/Q16174132 has no label
# entity http://www.wikidata.org/entity/Q16141765 has no label
# entity http://www.wikidata.org/entity/Q21655332 has no label
# entity http://www.wikidata.org/entity/Q52154536 has no label
# entity http://www.wikidata.org/entity/Q4426552 has no label
# entity http://www.wikidata.org/entity/Q1459364 has no label
# entity http://www.wikidata.org/entity/Q2515597 has no label
# entity http://www.wikidata.org/entity/Q2454505 has no label
# entity http://www.wikidata.org/entity/Q11698830 has no label
# entity http://www.wikidata.org/entity/Q102428640 has no label
# entity http://www.wikidata.org/entity/Q3227598 has no label
# entity http://www.wikidata.org/entity/Q1533391 has no label
# entity http://www.wikidata.org/entity/Q12100227 has no label
# entity http://www.wikidata.org/entity/Q97210756 has no label
# entity http://www.wikidata.org/entity/Q30740620 has no label
# entity http://www.wikidata.org/entity/Q23809303 has no label
# entity http://www.wikidata.org/entity/Q17263964 has no label
# entity http://www.wikidata.org/entity/Q30119440 has no label
# entity http://www.wikidata.org/entity/Q41695165 has no label
# entity http://www.wikidata.org/entity/Q104129141 has no label
# entity http://www.wikidata.org/entity/Q3225410 has no label
# entity http://www.wikidata.org/entity/Q5980862 has no label
# entity http://www.wikidata.org/entity/Q104641594 has no label
# entity http://www.wikidata.org/entity/Q104853525 has no label
# entity http://www.wikidata.org/entity/Q3224036 has no label
# entity http://www.wikidata.org/entity/Q2796478 has no label
# entity http://www.wikidata.org/entity/Q19198891 has no label
# entity http://www.wikidata.org/entity/Q104640367 has no label
# entity http://www.wikidata.org/entity/Q17053540 has no label

# %% [markdown]
# ### Make a dictionary of nodes URIs with the respective labels
#
# We want to make a dictionary in which the keys are the nodes URIs and the values are the nodes labels

# %%
# Function to extract the local part of a URI (e.g., after the last / or #)
def extract_label_from_uri(uri, namespaces):
    # Loop through all namespaces and remove the matching part
    for namespace in namespaces:
        if str(uri).startswith(str(namespace)):
            return str(uri).replace(str(namespace), "")
    # If no match, return the original URI
    return str(uri).split('/')[-1]

# Function to build a dictionary of nodes and their labels
def build_node_label_dict(graph, namespaces):
    nodes = {}
    
    for node in graph.all_nodes():
        if isinstance(node, rdflib.term.URIRef):  # Only process URIs
            # Check if the node has a label
            label = graph.value(node, RDFS.label)
            
            if label:
                # If label exists, use it
                nodes[node.toPython()] = str(label)
            else:
                # If no label, extract the local part of the URI
                local_label = extract_label_from_uri(node, namespaces)
                nodes[node.toPython()] = local_label
    
    return nodes

namespaces = [WD, WDT, DDIS, RDFS, SCHEMA]

nodes = build_node_label_dict(graph, namespaces)

# Check the result
for uri, label in nodes.items():
    print(f"URI: {uri}, Label: {label}")
    break
# Out:
# URI: http://www.wikidata.org/entity/Q1273264, Label: Michael Coulter

# %% [markdown]
# Make an inverse dictionary to find URIs of the entities given the labels

# %%
ent2uri = {ent: uri for uri, ent in nodes.items()}
# Out:
# http://www.wikidata.org/entity/Q18914861

# %% [markdown]
# We also make another dictionary specifically for predicates

# %%
# Function to build a dictionary of predicates and their labels
def build_pred_label_dict(graph, namespaces):
    predicates = {}
    
    for node in graph.predicates():
        if isinstance(node, rdflib.term.URIRef):  # Only process URIs
            # Check if the node has a label
            label = graph.value(node, RDFS.label)
            
            if label:
                # If label exists, use it
                predicates[node.toPython()] = str(label)

            # This condition is never evaluated cause all the predicates have labels
            else:
                # If no label, extract the local part of the URI
                local_label = extract_label_from_uri(node, namespaces)
                predicates[node.toPython()] = local_label
    
    return predicates

predicates = build_pred_label_dict(graph, namespaces)

# Check the result
for uri, label in predicates.items():
    print(f"URI: {uri}, Label: {label}")
    break
# Out:
# URI: http://www.w3.org/2000/01/rdf-schema#label, Label: node label

# %% [markdown]
# Make an inverse dictionary to find URIs of the predicates given the labels

# %%
pred2uri = {pred: uri for uri, pred in predicates.items()}

# %% [markdown]
# ### Matching function
#
# Suppose we find an entity "Batman_1989" in the question we want to answer. However "Batman_1989" is registered in the knowledge graph as "Batman 1989". We need a function that takes the entity from the questions and finds the closest entity in the knowledge graph

# %%
def match_entity(entity, dictionary=nodes):
    
    tmp = 9999
    match_node = ""
    match_value = ""
    
    for key, value in dictionary.items():

        if editdistance.eval(value, entity) == 0:

            return key, value
        
        if editdistance.eval(value, entity) < tmp:
            tmp = editdistance.eval(value, entity)
            match_node = key
            match_value = value
    
    return match_node, match_value

# %% [markdown]
# We can also use the match_entity function to match a predicate to the closest predicate in the graph by specifing dictionary=predicates
#
#
# For example:

# %%
match_node, match_value = match_entity('direcror', predicates)
print(f"URI: {match_node}, label: {match_value}")
# Out:
# URI: http://www.wikidata.org/prop/direct/P57, label: director

# %% [markdown]
# ### Processing questions
#
# Our first approach to answer factual question is very naive. The following function takes a question and tries to fit it to a series of questions patterns to extract a relation and an entity. For example the question "Who is the director of Batman" corresponds to pattern "who is the (?P<relation>.*) of (?P<entity>.*)". When we call method re.match on the question and the pattern it produces a match object (we call it match in the function) that contains a dictionary: {'relation': 'director', 'entity': Batman}. To access this dictionary we call .groupdict() on the match object (so match.groupdict() will be the dictionary). We retrieve relation and entity from the dictionary unsing get('relation') and get('entity') and specifing that if the dictionary doesn't have that key it should output "".

# %%
# List of patterns with named groups for 'relation' and 'entity'
question_patterns = [
    r"who is the (?P<relation>.*) of (?P<entity>.*)",   # e.g. who is the director of Batman
    r"what is the (?P<relation>.*) of (?P<entity>.*)",   # e.g. what is the movie rating of Batman
    r"when was (?P<entity>.*) (?P<relation>.*)",   # e.g. when was the godfather released
    r"who wrote the script of (?P<entity>.*)" # This one does not work with this approach
]

# Function to match the question to a pattern and extract relation and entity
def process_question(question, entity_dictionary, predicate_dictionary):
    
    for pattern in question_patterns:
        match = re.match(pattern, question, re.IGNORECASE)

        if match:
            # Extract relation and entity from named groups
            relation = match.groupdict().get('relation', "").lower()  # Set default as empty string
            entity = match.groupdict().get('entity', "")  # Set default as empty string
            
            # Match the entity to the closest in the knowledge graph
            matched_entity_uri, matched_entity_label = match_entity(entity, dictionary=entity_dictionary) if entity else (None, None)
            
            # Match the relation to the closest in the knowledge graph
            matched_predicate_uri, matched_predicate_label = match_entity(relation, dictionary=predicate_dictionary) if relation else (None, None)
            
            return matched_entity_uri, matched_entity_label, matched_predicate_uri, matched_predicate_label
    
    return None  # Return None if no pattern matches

# Example usage
question = "What is the release date of batman?" 
matched_entity_uri, matched_entity_label, matched_predicate_uri, matched_predicate_label = process_question(question, nodes, predicates)

print(f"Matched entity: {matched_entity_label} ({matched_entity_uri})")
print(f"Matched relation: {matched_predicate_label} ({matched_predicate_uri})")
# Out:
# Matched entity: Batman (http://www.wikidata.org/entity/Q4869384)
# Matched relation: relative (http://www.wikidata.org/prop/direct/P1038)

# %% [markdown]
# One problem with this is that relation "release date" is not correctly catched because it is closer to relation "relative" than it is to relation "publication date" which actually exists as a predicate in the knowledge graph
#
# IDEA TO FIX IT: modify the matching function for the predicates so that instead of relying on the edit distance it relies on embeddings similarity. Come back to this when you have started implementing embeddings

# %%
def query_graph(graph, entity_label, relation_predicate, namespaces):
    """
    Queries the graph to find the relation (e.g., director) of a given entity (e.g., movie).
    
    Args:
        graph (rdflib.Graph): The RDF graph to query.
        entity_label (str): The label of the entity (e.g., the movie title).
        relation_predicate (str): The predicate URI for the relation (e.g., director).
        namespaces (list): List of namespaces used in the graph.
    
    Returns:
        str: The result (e.g., director's name) or a message if no result is found.
    """
    # Define the query based on your format
    query_template = """
    SELECT ?result WHERE {{
        # ?entity rdfs:label "{}"@en .  
        # ?entity <{}> ?item . 
        # ?item rdfs:label ?result . 
    }}  
    """.format(entity_label, relation_predicate)

    print("--- SPARQL query ---")
    print(query_template)

    # Execute the query
    qres = graph.query(query_template)

    # Process the results
    results = []
    for row in qres:
        results.append(row.result)
    
    # Check if we have results, if not return a friendly message
    if results:
        for result in results:
            print(f"Answer: {result}")
        return results[0]  # Return the first result (as there is a LIMIT 1)
    else:
        return "No results found for the given query."

# %%
# Example usage:
entity_label = "Apocalypse Now"  # Movie title (entity)
relation_predicate = pred2uri['screenwriter']   # Predicate for 'director'

namespaces = [WD, WDT, DDIS, RDFS, SCHEMA]  # Your namespaces list
result = query_graph(graph, entity_label, relation_predicate, namespaces)

print(f"The director of {entity_label} is: {result}")
# Out:
# --- SPARQL query ---
#
#     SELECT ?result WHERE {
#         ?entity rdfs:label "Apocalypse Now"@en .
#         ?entity <http://www.wikidata.org/prop/direct/P58> ?item .
#         ?item rdfs:label ?result .
#     }
#
# Answer: Francis Ford Coppola
# Answer: John Milius
# Answer: Michael Herr
# The director of Apocalypse Now is: Francis Ford Coppola

# %%
# Example usage:
match_predicate = pred2uri['director']  
match_entity = ent2uri['Batman']

result = query_graph(graph, match_predicate, match_entity, namespaces)

print(result)  # This should print the answer returned by the SPARQL query
# Out:
# --- SPARQL query ---
#
#     SELECT ?result WHERE {
#         ?entity rdfs:label "http://www.wikidata.org/prop/direct/P57"@en .
#         ?entity <http://www.wikidata.org/entity/Q18914861> ?item .
#         ?item rdfs:label ?result .
#     }
#     LIMIT 1
#
# No results found for the given query.

# %%
print(graph.value(subject=WD.Q18914861, predicate=WDT.P57))
# Out:
# http://www.wikidata.org/entity/Q295207

# %%
print(ent2uri['Batman'])
# Out:
# http://www.wikidata.org/entity/Q18914861

# %%
print(pred2uri['director'])
# Out:
# http://www.wikidata.org/prop/direct/P57
